# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
EEG = pd.read_csv('/content/drive/MyDrive/EEG_data_1.csv')
#EG = pd.read_csv('EEG_data_1.csv')

# %%
# Display the first few rows of the dataset to inspect its structure
EEG.head(), EEG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68831 entries, 0 to 68830
# Data columns (total 87 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   subject_id          68831 non-null  int64
#  1   video_id            68831 non-null  int64
#  2   EEG.AF3             68831 non-null  float64
#  3   EEG.F7              68831 non-null  float64
#  4   EEG.F3              68831 non-null  float64
#  5   EEG.FC5             68831 non-null  float64
#  6   EEG.T7              68831 non-null  float64
#  7   EEG.P7              68831 non-null  float64
#  8   EEG.O1              68831 non-null  float64
#  9   EEG.O2              68831 non-null  float64
#  10  EEG.P8              68831 non-null  float64
#  11  EEG.T8              68831 non-null  float64
#  12  EEG.FC6             68831 non-null  float64
#  13  EEG.F4              68831 non-null  float64
#  14  EEG.F8              68831 non-null  float64
#  15  EEG.AF4             68831 non-null  float64
#  16  POW.AF3.Theta       68831 non-null  float64
#  17  POW.AF3.Alpha       68831 non-null  float64
#  18  POW.AF3.BetaL       68831 non-null  float64
#  19  POW.AF3.BetaH       68831 non-null  float64
#  20  POW.AF3.Gamma       68831 non-null  float64
#  21  POW.F7.Theta        68831 non-null  float64
#  22  POW.F7.Alpha        68831 non-null  float64
#  23  POW.F7.BetaL        68831 non-null  float64
#  24  POW.F7.BetaH        68831 non-null  float64
#  25  POW.F7.Gamma        68831 non-null  float64
#  26  POW.F3.Theta        68831 non-null  float64
#  27  POW.F3.Alpha        68831 non-null  float64
#  28  POW.F3.BetaL        68831 non-null  float64
#  29  POW.F3.BetaH        68831 non-null  float64
#  30  POW.F3.Gamma        68831 non-null  float64
#  31  POW.FC5.Theta       68831 non-null  float64
#  32  POW.FC5.Alpha       68831 non-null  float64
#  33  POW.FC5.BetaL       68831 non-null  float64
#  34  POW.FC5.BetaH       68831 non-null  float64
#  35  POW.FC5.Gamma       68831 non-null  float64
#  36  POW.T7.Theta        68831 non-null  float64
#  37  POW.T7.Alpha        68831 non-null  float64
#  38  POW.T7.BetaL        68831 non-null  float64
#  39  POW.T7.BetaH        68831 non-null  float64
#  40  POW.T7.Gamma        68831 non-null  float64
#  41  POW.P7.Theta        68831 non-null  float64
#  42  POW.P7.Alpha        68831 non-null  float64
#  43  POW.P7.BetaL        68831 non-null  float64
#  44  POW.P7.BetaH        68831 non-null  float64
#  45  POW.P7.Gamma        68831 non-null  float64
#  46  POW.O1.Theta        68831 non-null  float64
#  47  POW.O1.Alpha        68831 non-null  float64
#  48  POW.O1.BetaL        68831 non-null  float64
#  49  POW.O1.BetaH        68831 non-null  float64
#  50  POW.O1.Gamma        68831 non-null  float64
#  51  POW.O2.Theta        68831 non-null  float64
#  52  POW.O2.Alpha        68831 non-null  float64
#  53  POW.O2.BetaL        68831 non-null  float64
#  54  POW.O2.BetaH        68831 non-null  float64
#  55  POW.O2.Gamma        68831 non-null  float64
#  56  POW.P8.Theta        68831 non-null  float64
#  57  POW.P8.Alpha        68831 non-null  float64
#  58  POW.P8.BetaL        68831 non-null  float64
#  59  POW.P8.BetaH        68831 non-null  float64
#  60  POW.P8.Gamma        68831 non-null  float64
#  61  POW.T8.Theta        68831 non-null  float64
#  62  POW.T8.Alpha        68831 non-null  float64
#  63  POW.T8.BetaL        68831 non-null  float64
#  64  POW.T8.BetaH        68831 non-null  float64
#  65  POW.T8.Gamma        68831 non-null  float64
#  66  POW.FC6.Theta       68831 non-null  float64
#  67  POW.FC6.Alpha       68831 non-null  float64
#  68  POW.FC6.BetaL       68831 non-null  float64
#  69  POW.FC6.BetaH       68831 non-null  float64
#  70  POW.FC6.Gamma       68831 non-null  float64
#  71  POW.F4.Theta        68831 non-null  float64
#  72  POW.F4.Alpha        68831 non-null  float64
#  73  POW.F4.BetaL        68831 non-null  float64
#  74  POW.F4.BetaH        68831 non-null  float64
#  75  POW.F4.Gamma        68831 non-null  float64
#  76  POW.F8.Theta        68831 non-null  float64
#  77  POW.F8.Alpha        68831 non-null  float64
#  78  POW.F8.BetaL        68831 non-null  float64
#  79  POW.F8.BetaH        68831 non-null  float64
#  80  POW.F8.Gamma        68831 non-null  float64
#  81  POW.AF4.Theta       68831 non-null  float64
#  82  POW.AF4.Alpha       68831 non-null  float64
#  83  POW.AF4.BetaL       68831 non-null  float64
#  84  POW.AF4.BetaH       68831 non-null  float64
#  85  POW.AF4.Gamma       68831 non-null  float64
#  86  subject_understood  68831 non-null  int64
# dtypes: float64(84), int64(3)
# memory usage: 45.7 MB
# (   subject_id  video_id      EEG.AF3       EEG.F7       EEG.F3      EEG.FC5  \
#  0           0         0  4210.641113  4179.102539  4287.948730  4235.384766
#  1           0         0  4201.025879  4188.717773  4280.128418  4236.922852
#  2           0         0  4203.205078  4182.820313  4282.820313  4231.025879
#  3           0         0  4186.538574  4168.717773  4266.794922  4229.230957
#  4           0         0  4232.436035  4216.922852  4306.922852  4270.769043
#
#          EEG.T7       EEG.P7       EEG.O1       EEG.O2  ...  POW.F8.Alpha  \
#  0  4207.948730  4165.000000  4135.897461  4170.000000  ...      1.583895
#  1  4209.615234  4152.436035  4130.128418  4149.487305  ...      1.709560
#  2  4207.820313  4172.436035  4131.538574  4147.948730  ...      1.873591
#  3  4202.179688  4155.384766  4128.333496  4151.666504  ...      2.110017
#  4  4217.436035  4166.538574  4155.897461  4162.820313  ...      2.462552
#
#     POW.F8.BetaL  POW.F8.BetaH  POW.F8.Gamma  POW.AF4.Theta  POW.AF4.Alpha  \
#  0      0.504567      0.471979      0.138717       1.801014       1.504794
#  1      0.606587      0.527616      0.155580       1.859177       1.379617
#  2      0.795834      0.565414      0.170816       2.027946       1.283876
#  3      1.021118      0.579656      0.180056       2.265952       1.306188
#  4      1.230984      0.573620      0.181081       2.461205       1.522420
#
#     POW.AF4.BetaL  POW.AF4.BetaH  POW.AF4.Gamma  subject_understood
#  0       0.258570       0.435745       0.469483                   0
#  1       0.317579       0.468416       0.642560                   0
#  2       0.441925       0.494701       0.798197                   0
#  3       0.616881       0.506062       0.886495                   0
#  4       0.822598       0.498361       0.874455                   0
#
#  [5 rows x 87 columns],
#  None)

# %%
x= EEG.drop('subject_id', axis = 1)
y = EEG['subject_id']
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Normalize the data
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# Split the data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras import mixed_precision  # Import directly
import time
import psutil

# %%
# Enable mixed precision for energy-efficient training
policy = mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy) # Use set_global_policy instead of set_policy

# %%
# Enable mixed precision for energy-efficient training
#policy = mixed_precision.Policy('mixed_float16')
#mixed_precision.set_policy(policy)

# Define the 14-layer Deep Contractive Autoencoder
def build_energy_efficient_cae(input_dim, encoding_dim):
    input_layer = layers.Input(shape=(input_dim,))

    # Encoder
    encoded = layers.Dense(512, activation='swish')(input_layer)
    encoded = layers.Dense(256, activation='swish')(encoded)
    encoded = layers.Dense(128, activation='swish')(encoded)
    encoded = layers.Dense(64, activation='swish')(encoded)
    encoded = layers.Dense(32, activation='swish')(encoded)
    encoded = layers.Dense(encoding_dim, activation='swish', name='encoded_layer')(encoded)

    # Decoder
    decoded = layers.Dense(32, activation='swish')(encoded)
    decoded = layers.Dense(64, activation='swish')(decoded)
    decoded = layers.Dense(128, activation='swish')(decoded)
    decoded = layers.Dense(256, activation='swish')(decoded)
    decoded = layers.Dense(512, activation='swish')(decoded)
    output_layer = layers.Dense(input_dim, activation='elu')(decoded)

    # Autoencoder Model
    autoencoder = models.Model(inputs=input_layer, outputs=output_layer)

    return autoencoder

# Assuming X_train is already defined and preprocessed
#input_dim = x_train.shape[1]  # Dynamically set the input dimension based on X_train
input_dim = 86 # Set this to the correct input dimension
encoding_dim = 32  # Set the encoding dimension

# Build the model with the dynamic input dimension
autoencoder = build_energy_efficient_cae(input_dim, encoding_dim)

# Learning rate scheduler for energy-efficient training
def scheduler(epoch, lr):
    if epoch < 100:
        return lr
    elif epoch < 200:
        return lr * 0.5
    else:
        return lr * 0.1

lr_schedule = LearningRateScheduler(scheduler)

# Compile the model with mixed precision and an energy-efficient optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
autoencoder.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['accuracy'])

# Verify the shape of x_train
#print(x_train.shape)

# If the shape is not (None, 128), preprocess x_train to match the expected input dimension
# For example, if x_train currently has 86 features, you might need to pad or transform it
#from sklearn.preprocessing import StandardScaler, MinMaxScaler
#scaler = MinMaxScaler()
#x_train = scaler.fit_transform(x_train)
#x_test = scaler.transform(x_test)

# Train the deeper model
start_time = time.time()
# Retrain the model with the correctly shaped x_train data
history = autoencoder.fit(x_test, x_test,
                          epochs=300,
                          batch_size=32,
                          validation_data=(x_test, x_test),
                          shuffle=True,
                          callbacks=[lr_schedule])
end_time = time.time()
training_time = end_time - start_time
print(f"Training Time: {training_time} seconds")
# Save the trained model
autoencoder.save('energy_efficient_cae_14_layers.h5')

# Evaluate the model on the test set
evaluation = autoencoder.evaluate(x_test, x_test)
print(f"Test Loss: {evaluation[0]}, Test Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.2526 - loss: 0.3161 - val_accuracy: 0.3908 - val_loss: 0.3988 - learning_rate: 0.0010
# Epoch 2/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.4478 - loss: 0.2823 - val_accuracy: 0.5110 - val_loss: 0.4245 - learning_rate: 0.0010
# Epoch 3/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.5050 - loss: 1.4125 - val_accuracy: 0.4936 - val_loss: 0.3701 - learning_rate: 0.0010
# Epoch 4/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.4999 - loss: 0.2954 - val_accuracy: 0.5005 - val_loss: 0.4412 - learning_rate: 0.0010
# Epoch 5/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.5091 - loss: 0.4074 - val_accuracy: 0.5236 - val_loss: 0.3721 - learning_rate: 0.0010
# Epoch 6/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.5272 - loss: 0.1715 - val_accuracy: 0.5304 - val_loss: 0.4129 - learning_rate: 0.0010
# Epoch 7/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.5254 - loss: 0.2903 - val_accuracy: 0.5488 - val_loss: 0.3537 - learning_rate: 0.0010
# Epoch 8/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.5457 - loss: 0.2310 - val_accuracy: 0.5583 - val_loss: 0.4762 - learning_rate: 0.0010
# Epoch 9/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5587 - loss: 0.1863 - val_accuracy: 0.5529 - val_loss: 0.3836 - learning_rate: 0.0010
# Epoch 10/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.5521 - loss: 0.2561 - val_accuracy: 0.5623 - val_loss: 0.2798 - learning_rate: 0.0010
# Epoch 11/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.5559 - loss: 0.5114 - val_accuracy: 0.5512 - val_loss: 0.3174 - learning_rate: 0.0010
# Epoch 12/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.5484 - loss: 0.1941 - val_accuracy: 0.5544 - val_loss: 5.3281 - learning_rate: 0.0010
# Epoch 13/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.5336 - loss: 0.6935 - val_accuracy: 0.5579 - val_loss: 0.5461 - learning_rate: 0.0010
# Epoch 14/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.5513 - loss: 1.0560 - val_accuracy: 0.5634 - val_loss: 0.3864 - learning_rate: 0.0010
# Epoch 15/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5491 - loss: 0.4291 - val_accuracy: 0.5473 - val_loss: 0.2339 - learning_rate: 0.0010
# Epoch 16/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.5500 - loss: 1.0825 - val_accuracy: 0.5619 - val_loss: 0.2965 - learning_rate: 0.0010
# Epoch 17/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5594 - loss: 0.3102 - val_accuracy: 0.5611 - val_loss: 68.0314 - learning_rate: 0.0010
# Epoch 18/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.5534 - loss: 61.7791 - val_accuracy: 0.5680 - val_loss: 0.3732 - learning_rate: 0.0010
# Epoch 19/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.5666 - loss: 0.1745 - val_accuracy: 0.5621 - val_loss: 10.0804 - learning_rate: 0.0010
# Epoch 20/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - accuracy: 0.5251 - loss: 1.5152 - val_accuracy: 0.5196 - val_loss: 0.3879 - learning_rate: 0.0010
# Epoch 21/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 27s 40ms/step - accuracy: 0.5081 - loss: 0.5753 - val_accuracy: 0.5211 - val_loss: 0.2862 - learning_rate: 0.0010
# Epoch 22/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - accuracy: 0.5291 - loss: 0.3853 - val_accuracy: 0.5451 - val_loss: 0.2381 - learning_rate: 0.0010
# Epoch 23/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 0.5192 - loss: 1.0867 - val_accuracy: 0.5566 - val_loss: 0.3812 - learning_rate: 0.0010
# Epoch 24/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5395 - loss: 0.6438 - val_accuracy: 0.5497 - val_loss: 0.4068 - learning_rate: 0.0010
# Epoch 25/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.5435 - loss: 0.2765 - val_accuracy: 0.5467 - val_loss: 0.3727 - learning_rate: 0.0010
# Epoch 26/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 23s 31ms/step - accuracy: 0.5503 - loss: 0.2685 - val_accuracy: 0.5300 - val_loss: 9.0814 - learning_rate: 0.0010
# Epoch 27/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - accuracy: 0.5523 - loss: 0.8066 - val_accuracy: 0.5362 - val_loss: 0.3990 - learning_rate: 0.0010
# Epoch 28/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.5381 - loss: 0.2708 - val_accuracy: 0.5444 - val_loss: 0.3607 - learning_rate: 0.0010
# Epoch 29/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.5415 - loss: 0.3368 - val_accuracy: 0.5587 - val_loss: 13.3467 - learning_rate: 0.0010
# Epoch 30/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5462 - loss: 0.7638 - val_accuracy: 0.5550 - val_loss: 1.7119 - learning_rate: 0.0010
# Epoch 31/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.5499 - loss: 2.0942 - val_accuracy: 0.5672 - val_loss: 0.3814 - learning_rate: 0.0010
# Epoch 32/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.5326 - loss: 0.2954 - val_accuracy: 0.5470 - val_loss: 0.2463 - learning_rate: 0.0010
# Epoch 33/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - accuracy: 0.5445 - loss: 0.1697 - val_accuracy: 0.5460 - val_loss: 0.2935 - learning_rate: 0.0010
# Epoch 34/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.5235 - loss: 0.5478 - val_accuracy: 0.5738 - val_loss: 0.2750 - learning_rate: 0.0010
# Epoch 35/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5344 - loss: 0.2817 - val_accuracy: 0.5414 - val_loss: 0.3494 - learning_rate: 0.0010
# Epoch 36/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5349 - loss: 1.4430 - val_accuracy: 0.5757 - val_loss: 0.3799 - learning_rate: 0.0010
# Epoch 37/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.5547 - loss: 0.2900 - val_accuracy: 0.5455 - val_loss: 0.2644 - learning_rate: 0.0010
# Epoch 38/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.5519 - loss: 0.4010 - val_accuracy: 0.5396 - val_loss: 0.3905 - learning_rate: 0.0010
# Epoch 39/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5650 - loss: 0.3867 - val_accuracy: 0.5555 - val_loss: 0.3847 - learning_rate: 0.0010
# Epoch 40/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.5675 - loss: 0.1990 - val_accuracy: 0.5418 - val_loss: 3.1799 - learning_rate: 0.0010
# Epoch 41/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.5670 - loss: 0.2767 - val_accuracy: 0.5737 - val_loss: 0.3772 - learning_rate: 0.0010
# Epoch 42/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.5795 - loss: 0.2275 - val_accuracy: 0.5451 - val_loss: 0.3243 - learning_rate: 0.0010
# Epoch 43/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5352 - loss: 0.2463 - val_accuracy: 0.5267 - val_loss: 0.4022 - learning_rate: 0.0010
# Epoch 44/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5290 - loss: 0.2781 - val_accuracy: 0.5673 - val_loss: 0.2560 - learning_rate: 0.0010
# Epoch 45/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.5645 - loss: 0.2934 - val_accuracy: 0.5464 - val_loss: 0.3274 - learning_rate: 0.0010
# Epoch 46/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.5522 - loss: 0.3249 - val_accuracy: 0.5871 - val_loss: 0.4192 - learning_rate: 0.0010
# Epoch 47/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.5580 - loss: 0.3760 - val_accuracy: 0.5587 - val_loss: 0.2194 - learning_rate: 0.0010
# Epoch 48/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.5586 - loss: 0.2305 - val_accuracy: 0.5392 - val_loss: 0.4317 - learning_rate: 0.0010
# Epoch 49/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.5500 - loss: 0.8189 - val_accuracy: 0.5666 - val_loss: 0.3265 - learning_rate: 0.0010
# Epoch 50/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.5586 - loss: 0.5863 - val_accuracy: 0.5576 - val_loss: 0.4257 - learning_rate: 0.0010
# Epoch 51/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.5451 - loss: 0.2945 - val_accuracy: 0.5797 - val_loss: 0.3908 - learning_rate: 0.0010
# Epoch 52/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5631 - loss: 0.6610 - val_accuracy: 0.5900 - val_loss: 0.2305 - learning_rate: 0.0010
# Epoch 53/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.5764 - loss: 0.5446 - val_accuracy: 0.6000 - val_loss: 0.4049 - learning_rate: 0.0010
# Epoch 54/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.5843 - loss: 0.2030 - val_accuracy: 0.5212 - val_loss: 0.4604 - learning_rate: 0.0010
# Epoch 55/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5302 - loss: 0.4758 - val_accuracy: 0.5741 - val_loss: 0.4256 - learning_rate: 0.0010
# Epoch 56/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.5621 - loss: 0.7536 - val_accuracy: 0.5851 - val_loss: 0.4075 - learning_rate: 0.0010
# Epoch 57/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5852 - loss: 0.3637 - val_accuracy: 0.5592 - val_loss: 0.3979 - learning_rate: 0.0010
# Epoch 58/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5838 - loss: 0.4963 - val_accuracy: 0.5770 - val_loss: 0.3267 - learning_rate: 0.0010
# Epoch 59/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.5640 - loss: 0.4170 - val_accuracy: 0.5764 - val_loss: 0.2801 - learning_rate: 0.0010
# Epoch 60/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 41ms/step - accuracy: 0.5817 - loss: 0.3214 - val_accuracy: 0.5669 - val_loss: 0.3844 - learning_rate: 0.0010
# Epoch 61/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.5861 - loss: 0.2095 - val_accuracy: 0.5699 - val_loss: 0.3118 - learning_rate: 0.0010
# Epoch 62/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.5794 - loss: 0.2966 - val_accuracy: 0.5446 - val_loss: 0.4189 - learning_rate: 0.0010
# Epoch 63/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.5676 - loss: 0.6050 - val_accuracy: 0.5775 - val_loss: 0.3810 - learning_rate: 0.0010
# Epoch 64/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.5851 - loss: 0.2051 - val_accuracy: 0.5624 - val_loss: 0.3615 - learning_rate: 0.0010
# Epoch 65/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.5745 - loss: 0.3660 - val_accuracy: 0.5733 - val_loss: 0.3389 - learning_rate: 0.0010
# Epoch 66/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.5208 - loss: 0.5046 - val_accuracy: 0.5704 - val_loss: 0.4018 - learning_rate: 0.0010
# Epoch 67/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.5755 - loss: 0.2429 - val_accuracy: 0.5524 - val_loss: 0.4246 - learning_rate: 0.0010
# Epoch 68/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.5727 - loss: 0.2813 - val_accuracy: 0.5871 - val_loss: 0.6904 - learning_rate: 0.0010
# Epoch 69/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5905 - loss: 0.9077 - val_accuracy: 0.5740 - val_loss: 0.3612 - learning_rate: 0.0010
# Epoch 70/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 0.5837 - loss: 0.2804 - val_accuracy: 0.5847 - val_loss: 1.6819 - learning_rate: 0.0010
# Epoch 71/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.5867 - loss: 7.0003 - val_accuracy: 0.5637 - val_loss: 0.3757 - learning_rate: 0.0010
# Epoch 72/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.5813 - loss: 0.2154 - val_accuracy: 0.5542 - val_loss: 0.3957 - learning_rate: 0.0010
# Epoch 73/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.5597 - loss: 0.1750 - val_accuracy: 0.6038 - val_loss: 22.0623 - learning_rate: 0.0010
# Epoch 74/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.5798 - loss: 0.4159 - val_accuracy: 0.5555 - val_loss: 0.3843 - learning_rate: 0.0010
# Epoch 75/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.5404 - loss: 0.5050 - val_accuracy: 0.5371 - val_loss: 0.2218 - learning_rate: 0.0010
# Epoch 76/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5424 - loss: 0.2314 - val_accuracy: 0.5133 - val_loss: 0.3960 - learning_rate: 0.0010
# Epoch 77/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5276 - loss: 0.2241 - val_accuracy: 0.5346 - val_loss: 0.9321 - learning_rate: 0.0010
# Epoch 78/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.5316 - loss: 0.3072 - val_accuracy: 0.5607 - val_loss: 0.4108 - learning_rate: 0.0010
# Epoch 79/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.5452 - loss: 0.3757 - val_accuracy: 0.5590 - val_loss: 0.3620 - learning_rate: 0.0010
# Epoch 80/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 36s 39ms/step - accuracy: 0.5698 - loss: 0.3445 - val_accuracy: 0.5772 - val_loss: 0.1981 - learning_rate: 0.0010
# Epoch 81/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.5906 - loss: 0.2024 - val_accuracy: 0.6272 - val_loss: 5.5731 - learning_rate: 0.0010
# Epoch 82/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - accuracy: 0.5883 - loss: 0.2478 - val_accuracy: 0.5876 - val_loss: 0.3725 - learning_rate: 0.0010
# Epoch 83/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.5860 - loss: 0.2308 - val_accuracy: 0.5640 - val_loss: 3.2438 - learning_rate: 0.0010
# Epoch 84/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 24s 56ms/step - accuracy: 0.5749 - loss: 5.9239 - val_accuracy: 0.5130 - val_loss: 0.3754 - learning_rate: 0.0010
# Epoch 85/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 27s 24ms/step - accuracy: 0.5640 - loss: 0.2972 - val_accuracy: 0.5017 - val_loss: 0.3110 - learning_rate: 0.0010
# Epoch 86/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 25s 36ms/step - accuracy: 0.5350 - loss: 0.9009 - val_accuracy: 0.5802 - val_loss: 0.3766 - learning_rate: 0.0010
# Epoch 87/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.5559 - loss: 0.2217 - val_accuracy: 0.5665 - val_loss: 30.4080 - learning_rate: 0.0010
# Epoch 88/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.5631 - loss: 0.9605 - val_accuracy: 0.5603 - val_loss: 0.3695 - learning_rate: 0.0010
# Epoch 89/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.5499 - loss: 0.5560 - val_accuracy: 0.5608 - val_loss: 0.4147 - learning_rate: 0.0010
# Epoch 90/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.5864 - loss: 0.4344 - val_accuracy: 0.5949 - val_loss: 0.3661 - learning_rate: 0.0010
# Epoch 91/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.5890 - loss: 0.3001 - val_accuracy: 0.5991 - val_loss: 0.4305 - learning_rate: 0.0010
# Epoch 92/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5894 - loss: 0.2780 - val_accuracy: 0.5884 - val_loss: 0.3733 - learning_rate: 0.0010
# Epoch 93/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6113 - loss: 0.1885 - val_accuracy: 0.6009 - val_loss: 0.4228 - learning_rate: 0.0010
# Epoch 94/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.6052 - loss: 1.3994 - val_accuracy: 0.5953 - val_loss: 0.4098 - learning_rate: 0.0010
# Epoch 95/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - accuracy: 0.6154 - loss: 0.8598 - val_accuracy: 0.5817 - val_loss: 0.4074 - learning_rate: 0.0010
# Epoch 96/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.5852 - loss: 0.4035 - val_accuracy: 0.5697 - val_loss: 1.0378 - learning_rate: 0.0010
# Epoch 97/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.5819 - loss: 0.2061 - val_accuracy: 0.5436 - val_loss: 0.3335 - learning_rate: 0.0010
# Epoch 98/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.5533 - loss: 0.2606 - val_accuracy: 0.5834 - val_loss: 0.4090 - learning_rate: 0.0010
# Epoch 99/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5532 - loss: 0.4112 - val_accuracy: 0.5837 - val_loss: 0.3268 - learning_rate: 0.0010
# Epoch 100/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.5799 - loss: 0.3400 - val_accuracy: 0.5771 - val_loss: 1.0974 - learning_rate: 0.0010
# Epoch 101/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.5680 - loss: 1.1538 - val_accuracy: 0.6126 - val_loss: 6.3143 - learning_rate: 5.0000e-04
# Epoch 102/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6100 - loss: 0.2118 - val_accuracy: 0.5967 - val_loss: 1.6736 - learning_rate: 2.5000e-04
# Epoch 103/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6163 - loss: 0.4399 - val_accuracy: 0.6186 - val_loss: 1.6955 - learning_rate: 1.2500e-04
# Epoch 104/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6226 - loss: 2.1800 - val_accuracy: 0.6336 - val_loss: 0.3455 - learning_rate: 6.2500e-05
# Epoch 105/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6261 - loss: 0.3758 - val_accuracy: 0.6232 - val_loss: 0.2935 - learning_rate: 3.1250e-05
# Epoch 106/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6157 - loss: 0.2662 - val_accuracy: 0.6197 - val_loss: 0.2744 - learning_rate: 1.5625e-05
# Epoch 107/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6204 - loss: 0.2287 - val_accuracy: 0.6229 - val_loss: 0.2644 - learning_rate: 7.8125e-06
# Epoch 108/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.6210 - loss: 0.2676 - val_accuracy: 0.6224 - val_loss: 0.2599 - learning_rate: 3.9063e-06
# Epoch 109/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6214 - loss: 0.4245 - val_accuracy: 0.6227 - val_loss: 0.2582 - learning_rate: 1.9531e-06
# Epoch 110/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6194 - loss: 0.2120 - val_accuracy: 0.6232 - val_loss: 0.2566 - learning_rate: 9.7656e-07
# Epoch 111/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6244 - loss: 0.2882 - val_accuracy: 0.6234 - val_loss: 0.2557 - learning_rate: 4.8828e-07
# Epoch 112/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6225 - loss: 0.2602 - val_accuracy: 0.6232 - val_loss: 0.2556 - learning_rate: 2.4414e-07
# Epoch 113/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6237 - loss: 0.2245 - val_accuracy: 0.6228 - val_loss: 0.2552 - learning_rate: 1.2207e-07
# Epoch 114/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 29s 47ms/step - accuracy: 0.6227 - loss: 0.1928 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 6.1035e-08
# Epoch 115/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.6290 - loss: 0.3089 - val_accuracy: 0.6237 - val_loss: 0.2547 - learning_rate: 3.0518e-08
# Epoch 116/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.6116 - loss: 0.2180 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.5259e-08
# Epoch 117/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - accuracy: 0.6242 - loss: 0.1788 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.6294e-09
# Epoch 118/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.6231 - loss: 0.2434 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.8147e-09
# Epoch 119/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 24s 42ms/step - accuracy: 0.6273 - loss: 0.2152 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.9073e-09
# Epoch 120/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - accuracy: 0.6232 - loss: 0.2153 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 9.5367e-10
# Epoch 121/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.6260 - loss: 0.3532 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.7684e-10
# Epoch 122/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.6262 - loss: 0.2211 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.3842e-10
# Epoch 123/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6245 - loss: 0.2872 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.1921e-10
# Epoch 124/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6239 - loss: 0.1680 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.9605e-11
# Epoch 125/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.6231 - loss: 0.1727 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.9802e-11
# Epoch 126/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6208 - loss: 0.1965 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.4901e-11
# Epoch 127/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6238 - loss: 0.2745 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.4506e-12
# Epoch 128/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.6213 - loss: 0.1732 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.7253e-12
# Epoch 129/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6170 - loss: 0.2818 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.8626e-12
# Epoch 130/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6313 - loss: 0.3322 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 9.3132e-13
# Epoch 131/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.6232 - loss: 0.1583 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.6566e-13
# Epoch 132/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6325 - loss: 0.1692 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.3283e-13
# Epoch 133/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.6277 - loss: 0.1545 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.1642e-13
# Epoch 134/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6261 - loss: 0.1843 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.8208e-14
# Epoch 135/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6240 - loss: 0.2172 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.9104e-14
# Epoch 136/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.6213 - loss: 0.1622 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.4552e-14
# Epoch 137/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.6196 - loss: 0.3334 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.2760e-15
# Epoch 138/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.6278 - loss: 0.3224 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.6380e-15
# Epoch 139/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.6217 - loss: 0.2543 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.8190e-15
# Epoch 140/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.6208 - loss: 0.3548 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 9.0949e-16
# Epoch 141/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6204 - loss: 0.3311 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.5475e-16
# Epoch 142/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6164 - loss: 0.1781 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.2737e-16
# Epoch 143/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6240 - loss: 0.3634 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.1369e-16
# Epoch 144/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6208 - loss: 0.2267 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.6843e-17
# Epoch 145/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6236 - loss: 0.1731 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.8422e-17
# Epoch 146/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6170 - loss: 0.2026 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.4211e-17
# Epoch 147/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6244 - loss: 0.1798 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.1054e-18
# Epoch 148/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6242 - loss: 0.2049 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.5527e-18
# Epoch 149/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6313 - loss: 0.1851 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.7764e-18
# Epoch 150/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6253 - loss: 0.3540 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 8.8818e-19
# Epoch 151/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.6214 - loss: 0.3366 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.4409e-19
# Epoch 152/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6259 - loss: 0.4307 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.2204e-19
# Epoch 153/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6192 - loss: 0.2347 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.1102e-19
# Epoch 154/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.6214 - loss: 0.1987 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.5511e-20
# Epoch 155/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.6287 - loss: 0.1582 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.7756e-20
# Epoch 156/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.6225 - loss: 0.3034 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.3878e-20
# Epoch 157/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.6213 - loss: 0.1836 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 6.9389e-21
# Epoch 158/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6237 - loss: 0.1768 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.4694e-21
# Epoch 159/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6199 - loss: 0.2621 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.7347e-21
# Epoch 160/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6141 - loss: 0.2073 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 8.6736e-22
# Epoch 161/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.6303 - loss: 0.2411 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.3368e-22
# Epoch 162/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6200 - loss: 0.2639 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.1684e-22
# Epoch 163/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.6216 - loss: 0.2702 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.0842e-22
# Epoch 164/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.6277 - loss: 0.1486 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.4210e-23
# Epoch 165/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6229 - loss: 0.2268 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.7105e-23
# Epoch 166/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6133 - loss: 0.1403 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.3553e-23
# Epoch 167/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6177 - loss: 0.3373 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 6.7763e-24
# Epoch 168/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.6219 - loss: 0.1701 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.3881e-24
# Epoch 169/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6311 - loss: 0.2693 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.6941e-24
# Epoch 170/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6246 - loss: 0.2729 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 8.4703e-25
# Epoch 171/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6223 - loss: 0.2399 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.2352e-25
# Epoch 172/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6210 - loss: 0.2202 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.1176e-25
# Epoch 173/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.6165 - loss: 0.1731 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.0588e-25
# Epoch 174/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.6238 - loss: 0.1534 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.2940e-26
# Epoch 175/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6195 - loss: 0.2134 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.6470e-26
# Epoch 176/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.6355 - loss: 0.2976 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.3235e-26
# Epoch 177/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6247 - loss: 0.2265 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 6.6174e-27
# Epoch 178/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.6265 - loss: 0.4316 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.3087e-27
# Epoch 179/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6244 - loss: 0.1747 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.6544e-27
# Epoch 180/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.6312 - loss: 0.3039 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 8.2718e-28
# Epoch 181/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6187 - loss: 0.2155 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.1359e-28
# Epoch 182/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6212 - loss: 0.2967 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.0680e-28
# Epoch 183/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6274 - loss: 0.2352 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.0340e-28
# Epoch 184/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.6213 - loss: 0.1871 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.1699e-29
# Epoch 185/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6201 - loss: 0.2224 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.5849e-29
# Epoch 186/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.6218 - loss: 0.3838 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.2925e-29
# Epoch 187/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - accuracy: 0.6233 - loss: 0.2496 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 6.4623e-30
# Epoch 188/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6218 - loss: 0.2520 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.2312e-30
# Epoch 189/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.6225 - loss: 0.2505 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.6156e-30
# Epoch 190/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.6280 - loss: 0.2516 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 8.0779e-31
# Epoch 191/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.6173 - loss: 0.6549 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 4.0390e-31
# Epoch 192/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6206 - loss: 0.3224 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.0195e-31
# Epoch 193/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6176 - loss: 0.2658 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.0097e-31
# Epoch 194/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.6229 - loss: 0.3199 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 5.0487e-32
# Epoch 195/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6195 - loss: 0.1739 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 2.5244e-32
# Epoch 196/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.6267 - loss: 0.4491 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.2622e-32
# Epoch 197/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.6196 - loss: 0.3056 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 6.3109e-33
# Epoch 198/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6250 - loss: 0.2848 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 3.1554e-33
# Epoch 199/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6179 - loss: 0.2521 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.5777e-33
# Epoch 200/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.6172 - loss: 0.2379 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-34
# Epoch 201/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6219 - loss: 0.2021 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-35
# Epoch 202/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6266 - loss: 0.2239 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-36
# Epoch 203/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.6253 - loss: 0.3164 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-37
# Epoch 204/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - accuracy: 0.6230 - loss: 0.1649 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-38
# Epoch 205/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - accuracy: 0.6252 - loss: 0.1840 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-39
# Epoch 206/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.6277 - loss: 0.1569 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-40
# Epoch 207/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.6239 - loss: 0.2870 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8886e-41
# Epoch 208/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6198 - loss: 0.2462 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8893e-42
# Epoch 209/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6277 - loss: 0.2500 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8893e-43
# Epoch 210/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.6229 - loss: 0.3174 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 7.8473e-44
# Epoch 211/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.6307 - loss: 0.4153 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 8.4078e-45
# Epoch 212/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.6229 - loss: 0.1901 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 1.4013e-45
# Epoch 213/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.6216 - loss: 0.2179 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 214/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6273 - loss: 0.1870 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 215/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.6271 - loss: 0.2352 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 216/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6196 - loss: 0.2151 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 217/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6264 - loss: 0.2801 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 218/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.6284 - loss: 0.2281 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 219/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6293 - loss: 0.2912 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 220/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6266 - loss: 0.2426 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 221/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6177 - loss: 0.2496 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 222/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6209 - loss: 0.3306 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 223/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - accuracy: 0.6214 - loss: 0.1607 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 224/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6254 - loss: 0.1878 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 225/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6293 - loss: 0.2065 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 226/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6190 - loss: 0.1943 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 227/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6190 - loss: 0.2392 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 228/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.6208 - loss: 0.2446 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 229/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.6281 - loss: 0.2562 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 230/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6256 - loss: 0.2168 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 231/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6211 - loss: 0.1622 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 232/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.6235 - loss: 0.5590 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 233/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.6227 - loss: 0.2053 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 234/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.6233 - loss: 0.1901 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 235/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6262 - loss: 0.1886 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 236/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6196 - loss: 0.3475 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 237/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.6184 - loss: 0.4429 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 238/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6214 - loss: 0.3471 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 239/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6250 - loss: 0.2993 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 240/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.6323 - loss: 0.3075 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 241/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.6222 - loss: 0.3034 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 242/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.6275 - loss: 0.1767 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 243/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6210 - loss: 0.3325 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 244/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6308 - loss: 0.3593 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 245/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.6190 - loss: 0.3602 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 246/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.6242 - loss: 0.2604 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 247/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6263 - loss: 0.2312 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 248/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.6242 - loss: 0.1925 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 249/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6256 - loss: 0.3066 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 250/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6198 - loss: 0.2763 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 251/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.6292 - loss: 0.3874 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 252/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.6286 - loss: 0.3079 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 253/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.6259 - loss: 0.2895 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 254/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.6255 - loss: 0.3304 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 255/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6249 - loss: 0.2413 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 256/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - accuracy: 0.6168 - loss: 0.1433 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 257/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6259 - loss: 0.1683 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 258/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6178 - loss: 0.4995 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 259/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6253 - loss: 0.3576 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 260/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - accuracy: 0.6228 - loss: 0.2976 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 261/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6243 - loss: 0.2434 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 262/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6195 - loss: 0.2346 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 263/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6252 - loss: 0.2819 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 264/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.6223 - loss: 0.3040 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 265/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.6265 - loss: 0.3103 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 266/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6282 - loss: 0.2057 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 267/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.6268 - loss: 0.2713 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 268/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.6281 - loss: 0.2107 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 269/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6282 - loss: 0.2633 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 270/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.6248 - loss: 0.1605 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 271/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6248 - loss: 0.2051 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 272/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6239 - loss: 0.2162 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 273/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.6187 - loss: 0.1990 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 274/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6153 - loss: 0.2351 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 275/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6271 - loss: 0.1587 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 276/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.6192 - loss: 0.2797 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 277/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.6241 - loss: 0.3246 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 278/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6212 - loss: 0.2577 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 279/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - accuracy: 0.6238 - loss: 0.2037 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 280/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.6205 - loss: 0.4295 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 281/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 33ms/step - accuracy: 0.6157 - loss: 0.3140 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 282/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - accuracy: 0.6212 - loss: 0.3330 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 283/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6257 - loss: 0.1519 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 284/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.6264 - loss: 0.2110 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 285/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6176 - loss: 0.1827 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 286/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.6245 - loss: 0.3114 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 287/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - accuracy: 0.6229 - loss: 0.2940 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 288/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.6284 - loss: 0.4167 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 289/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 31ms/step - accuracy: 0.6250 - loss: 0.1924 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 290/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.6248 - loss: 0.3352 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 291/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - accuracy: 0.6221 - loss: 0.2881 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 292/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.6201 - loss: 0.1654 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 293/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.6169 - loss: 0.3257 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 294/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.6263 - loss: 0.2514 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 295/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6241 - loss: 0.3985 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 296/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6236 - loss: 0.2417 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 297/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6179 - loss: 0.2655 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 298/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.6191 - loss: 0.2332 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 299/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - accuracy: 0.6250 - loss: 0.4398 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# Epoch 300/300
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.6225 - loss: 0.2757 - val_accuracy: 0.6234 - val_loss: 0.2547 - learning_rate: 0.0000e+00
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training Time: 5023.01812171936 seconds
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6208 - loss: 0.4548
# Test Loss: 0.25465354323387146, Test Accuracy: 0.6233747601509094

# %%
# Predict and evaluate
#y_pred = autoencoder.predict(x_test) # Use the trained autoencoder to predict
mse = mean_squared_error(x_test, y_pred) # Calculate MSE

# Resource usage
cpu_start = psutil.cpu_percent(interval=1)
memory_start = psutil.virtual_memory().percent

inference_time = end_time - start_time

cpu_end = psutil.cpu_percent(interval=1)
memory_end = psutil.virtual_memory().percent

energy_consumption = inference_time * (cpu_end - cpu_start + memory_end - memory_start)

print(f"Mean Squared Error: {mse:.4f}")
print(f"Inference Time: {inference_time:.4f} seconds")
print(f"Estimated Energy Consumption: {energy_consumption:.4f} (proxy value)")

# Plotting
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Metrics Plot
plt.subplot(1, 2, 2)
plt.bar(['MSE'], [mse], color='skyblue')
plt.title('Mean Squared Error')
plt.ylabel('Values')

plt.tight_layout()
plt.show()
# Out:
# Mean Squared Error: 0.2547
# Inference Time: 5023.0181 seconds
# Estimated Energy Consumption: 7534.5272 (proxy value)

# %%
# You can also plot the encoded representations and the reconstructed outputs for further analysis
#encoded_imgs = encoder.predict(x_test)
#decoded_imgs = autoencoder.predict(x_test)

# Extract the encoder model
encoder = models.Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('encoded_layer').output)

# You can also plot the encoded representations and the reconstructed outputs for further analysis
#encoded_imgs = encoder.predict(x_test)  # Now using the defined 'encoder'
#decoded_imgs = autoencoder.predict(x_test)

# Visualizing the original, encoded, and reconstructed signals
n = 10  # Number of samples to plot
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(3, n, i + 1)
    plt.plot(x_test[i])
    plt.title("Original")

    # Encoded
    ax = plt.subplot(3, n, i + 1 + n)
    plt.plot(encoded_imgs[i])
    plt.title("Encoded")

    # Reconstructed
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.plot(decoded_imgs[i])
    plt.title("Reconstructed")
plt.show()

# %%
# Plot training history
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy') # Changed from 'mean_squared_error' to 'accuracy'
plt.plot(history.history['val_accuracy'], label='Validation Accuracy') # Changed from 'val_mae' to 'val_accuracy'
plt.title('Accuracy') # Changed title to reflect the correct metric
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Additional checks
# Removed the accuracy calculation and overfitting check as they were not appropriate for this model

# %%
import sklearn.metrics as metrics # Import the metrics module from sklearn
#predictions = autoencoder.predict(x_test)
mse = metrics.mean_squared_error(x_test, predictions) # Use metrics.mean_squared_error
r2 = metrics.r2_score(x_test, predictions) # Use metrics.r2_score

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')

# Plotting Loss Curve
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.legend()

# Plotting Actual vs Predicted
#plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(x_test[0], label='Actual Signal')
plt.plot(predictions[0], label='Reconstructed Signal')
plt.title('Actual vs Reconstructed EEG Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()


plt.tight_layout()
plt.show()
# Out:
# Mean Squared Error: 0.2546535009028007
# R^2 Score: 0.5399380055172927

# %%
# Function to plot original and reconstructed signals
def plot_signal_comparison(original, reconstructed, num_signals=5):
    plt.figure(figsize=(15, num_signals * 3))
    for i in range(num_signals):
        # Original Signal
        plt.subplot(num_signals, 2, 2*i + 1)
        plt.plot(original[i], color='blue')
        plt.title(f'Original Signal {i+1}')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.grid(True)

        # Reconstructed Signal
        plt.subplot(num_signals, 2, 2*i + 2)
        plt.plot(reconstructed[i], color='red')
        plt.title(f'Reconstructed Signal {i+1}')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.grid(True)
    plt.tight_layout()
    plt.show()

# Plotting comparison
plot_signal_comparison(x_test, predictions, num_signals=3)

# %%
# Predict and evaluate
x_pred_train = autoencoder.predict(x_train)
x_pred_test = autoencoder.predict(x_test)

# Calculate accuracy for reconstruction (simplified)
from sklearn.metrics import accuracy_score
def calculate_accuracy(x, x_pred):
    return np.mean([accuracy_score(np.round(x[i]), np.round(x_pred[i])) for i in range(len(x))])

train_accuracy = calculate_accuracy(x_train, x_pred_train)
test_accuracy = calculate_accuracy(x_test, x_pred_test)

# %%
# Predict and evaluate
x_pred_train = autoencoder.predict(x_train)
x_pred_test = autoencoder.predict(x_test)

# Calculate accuracy for reconstruction (simplified)
from sklearn.metrics import accuracy_score # Import accuracy_score from sklearn.metrics

def calculate_accuracy(x, x_pred):
    return np.mean([accuracy_score(np.round(x[i]), np.round(x_pred[i])) for i in range(len(x))])

train_accuracy = calculate_accuracy(x_train, x_pred_train)
test_accuracy = calculate_accuracy(x_test, x_pred_test)

# %%
# Example performance metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np # Import numpy

# Obtain predictions from the autoencoder
predictions = autoencoder.predict(x_test)

# Ensure that y_test and predictions have the same number of columns
# You may need to adjust the reshaping based on the actual shape of your data
if y_test.shape[1] != predictions.shape[1]:
    y_test = y_test.reshape(predictions.shape)

mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# %%
# Example performance metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np # Import numpy

# Obtain predictions from the autoencoder
predictions = autoencoder.predict(x_test)

# Ensure that y_test and predictions have compatible shapes
# Check if y_test needs to be reshaped or if a different target variable is needed
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# %%
# Example performance metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np # Import numpy

# Obtain predictions from the autoencoder
predictions = autoencoder.predict(x_test)

mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# %%
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# %%
# Example performance metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np # Import numpy

# Obtain predictions from the autoencoder
predictions = autoencoder.predict(x_test)

# Ensure that y_test and predictions have compatible shapes
# Check if y_test needs to be reshaped or if a different target variable is needed
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# %%
# Example performance metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np # Import numpy

# Obtain predictions from the autoencoder
predictions = autoencoder.predict(x_test)

# Ensure that y_test and predictions have compatible shapes
# Check if y_test needs to be reshaped or if a different target variable is needed
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mse)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# %%
# Ensure accuracy is at least 90%
assert test_accuracy >= 0.9, "Accuracy did not reach 90%."

# Plot loss graph
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Extracting latent features from test data
latent_features = encoder.predict(x_test)

print(f"Shape of latent features: {latent_features.shape}")
# Out:
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Shape of latent features: (13767, 32)

# %%
# Define the 14-layer Deep Contractive Autoencoder with dynamic activation function
def build_energy_efficient_cae(input_dim, encoding_dim, activation_choice):
    input_layer = layers.Input(shape=(input_dim,))

    # Encoder
    encoded = layers.Dense(512, activation=activation_choice)(input_layer)
    encoded = layers.Dense(256, activation=activation_choice)(encoded)
    encoded = layers.Dense(128, activation=activation_choice)(encoded)
    encoded = layers.Dense(64, activation=activation_choice)(encoded)
    encoded = layers.Dense(32, activation=activation_choice)(encoded)
    encoded = layers.Dense(encoding_dim, activation=activation_choice, name='encoded_layer')(encoded)

    # Decoder
    decoded = layers.Dense(32, activation=activation_choice)(encoded)
    decoded = layers.Dense(64, activation=activation_choice)(decoded)
    decoded = layers.Dense(128, activation=activation_choice)(decoded)
    decoded = layers.Dense(256, activation=activation_choice)(decoded)
    decoded = layers.Dense(512, activation=activation_choice)(decoded)
    output_layer = layers.Dense(input_dim, activation='elu')(decoded)

    # Autoencoder Model
    autoencoder = models.Model(inputs=input_layer, outputs=output_layer)

    return autoencoder

# %%
# Define hyperparameter choice for activation (dynamic activation function)
activation_choice = tf.keras.activations.swish  # Options: tf.keras.activations.relu, tf.keras.activations.elu, tf.keras.activations.swish

# Input dimensions (replace with actual dimensions from your dataset)
input_dim = x_train.shape[1]
encoding_dim = 32

# Build the model with the chosen activation function
autoencoder = build_energy_efficient_cae(input_dim, encoding_dim, activation_choice)

# %%
# Learning rate scheduler for energy-efficient training
def scheduler(epoch, lr):
    if epoch < 100:
        return lr
    elif epoch < 200:
        return lr * 0.5
    else:
        return lr * 0.1

lr_schedule = LearningRateScheduler(scheduler)

# Compile the model with Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
autoencoder.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['accuracy'])

# %%
# Start timing the training process
start_time = time.time()

# Train the model
history = autoencoder.fit(x_train, x_train,  # Make sure x_train is preprocessed
                          epochs=300,
                          batch_size=32,
                          validation_data=(x_test, x_test),  # Ensure x_test is preprocessed
                          shuffle=True,
                          callbacks=[lr_schedule])

# End timing
end_time = time.time()
training_time = end_time - start_time
print(f"Training Time: {training_time} seconds")

# Save the trained model
autoencoder.save('energy_efficient_cae_14_layers.h5')

# Evaluate the model on the test set
evaluation = autoencoder.evaluate(x_test, x_test)
print(f"Test Loss: {evaluation[0]}, Test Accuracy: {evaluation[1]}")

# Print CPU usage and memory usage for energy-efficient tracking
cpu_usage = psutil.cpu_percent()
memory_usage = psutil.virtual_memory().percent
print(f"CPU Usage: {cpu_usage}%, Memory Usage: {memory_usage}%")
# Out:
# Epoch 1/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.2981 - loss: 0.5161 - val_accuracy: 0.4878 - val_loss: 0.4582 - learning_rate: 0.0010
# Epoch 2/300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-06edd6d74352> in <cell line: 5>()
#       3
#       4 # Train the model
# ----> 5 history = autoencoder.fit(x_train, x_train,  # Make sure x_train is preprocessed
#       6                           epochs=300,
#       7                           batch_size=32,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     315             with epoch_iterator.catch_stop_iteration():
#     316                 for step, iterator in epoch_iterator.enumerate_epoch():
# --> 317                     callbacks.on_train_batch_begin(step)
#     318                     logs = self.train_function(iterator)
#     319                     logs = self._pythonify_logs(logs)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/callback_list.py in on_train_batch_begin(self, batch, logs)
#      96             callback.on_epoch_end(epoch, logs)
#      97
# ---> 98     def on_train_batch_begin(self, batch, logs=None):
#      99         logs = logs or {}
#     100         for callback in self.callbacks:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import LearningRateScheduler
import time
import psutil

# Define a function to build the 14-layer Deep Contractive Autoencoder with dynamic variables
def build_energy_efficient_cae(input_dim, encoding_dim, activation_choice):
    input_layer = layers.Input(shape=(input_dim,))

    # Encoder with dynamic activation function
    encoded = layers.Dense(512, activation=activation_choice)(input_layer)
    encoded = layers.Dense(256, activation=activation_choice)(encoded)
    encoded = layers.Dense(128, activation=activation_choice)(encoded)
    encoded = layers.Dense(64, activation=activation_choice)(encoded)
    encoded = layers.Dense(32, activation=activation_choice)(encoded)
    encoded = layers.Dense(encoding_dim, activation=activation_choice, name='encoded_layer')(encoded)

    # Decoder with dynamic activation function
    decoded = layers.Dense(32, activation=activation_choice)(encoded)
    decoded = layers.Dense(64, activation=activation_choice)(decoded)
    decoded = layers.Dense(128, activation=activation_choice)(decoded)
    decoded = layers.Dense(256, activation=activation_choice)(decoded)
    decoded = layers.Dense(512, activation=activation_choice)(decoded)
    output_layer = layers.Dense(input_dim, activation='elu')(decoded)  # ELU for the output layer

    # Autoencoder Model
    autoencoder = models.Model(inputs=input_layer, outputs=output_layer)

    return autoencoder

# Define hyperparameters as dynamic variables
#input_dim = 86  # Replace with actual input dimension
input_dim = x_train.shape[1]
encoding_dim = 32  # Latent encoding dimension, adjust as needed

# Dynamic selection for activation function (Swish, ReLU, ELU)
activation_choice = tf.keras.activations.swish  # You can also use 'relu' or 'elu'

# Dynamic learning rate for Adam optimizer
learning_rate = 0.001
weight_decay = 0.01  # Dynamic weight decay for regularization


# Build the model with dynamic input dimension, encoding dimension, and activation
autoencoder = build_energy_efficient_cae(input_dim, encoding_dim, activation_choice)

# Define dynamic learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 100:
        return lr
    elif epoch < 200:
        return lr * 0.5
    else:
        return lr * 0.1

lr_schedule = LearningRateScheduler(scheduler)

# Build the model with dynamic input dimension, encoding dimension, and activation
autoencoder = build_energy_efficient_cae(input_dim, encoding_dim, activation_choice)

# Dynamic optimizer selection (Adam, RMSprop, SGD, etc.)
#optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Dynamic learning rate
optimizer = tf.keras.optimizers.AdamW(learning_rate=learning_rate, weight_decay=weight_decay)

# Compile the model with dynamic optimizer and loss function
autoencoder.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['accuracy'])

# Simulate data for training and testing (replace these with your actual dataset)
#x_train = tf.random.normal((1000, input_dim))  # Replace with your actual preprocessed dataset
#x_test = tf.random.normal((200, input_dim))    # Replace with your actual preprocessed test dataset

# Start timing the training process
start_time = time.time()

# Train the model with dynamic batch size, epochs, and data
history = autoencoder.fit(x_train, x_train,  # Training data
                          epochs=300,  # Dynamic number of epochs
                          batch_size=32,  # Dynamic batch size
                          validation_data=(x_test, x_test),  # Validation data
                          shuffle=True,
                          callbacks=[lr_schedule])

# End timing
end_time = time.time()
training_time = end_time - start_time
print(f"Training Time: {training_time} seconds")

# Save the trained model
autoencoder.save('energy_efficient_cae_14_layers_dynamic.h5')

# Evaluate the model on the test set
evaluation = autoencoder.evaluate(x_test, x_test)
print(f"Test Loss: {evaluation[0]}, Test Accuracy: {evaluation[1]}")

# Print CPU usage and memory usage for energy-efficient tracking
cpu_usage = psutil.cpu_percent()
memory_usage = psutil.virtual_memory().percent
print(f"CPU Usage: {cpu_usage}%, Memory Usage: {memory_usage}%")
# Out:
# Epoch 1/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.3126 - loss: 0.8300 - val_accuracy: 0.5306 - val_loss: 1.1374 - learning_rate: 0.0010
# Epoch 2/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.4827 - loss: 1.4995 - val_accuracy: 0.4984 - val_loss: 0.2629 - learning_rate: 0.0010
# Epoch 3/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.4930 - loss: 3.0220 - val_accuracy: 0.5126 - val_loss: 0.4064 - learning_rate: 0.0010
# Epoch 4/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - accuracy: 0.5042 - loss: 0.7509 - val_accuracy: 0.5061 - val_loss: 0.4236 - learning_rate: 0.0010
# Epoch 5/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 21ms/step - accuracy: 0.5114 - loss: 0.6940 - val_accuracy: 0.5173 - val_loss: 0.4561 - learning_rate: 0.0010
# Epoch 6/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.5137 - loss: 0.8675 - val_accuracy: 0.5451 - val_loss: 0.4198 - learning_rate: 0.0010
# Epoch 7/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5280 - loss: 1.0426 - val_accuracy: 0.5441 - val_loss: 0.8123 - learning_rate: 0.0010
# Epoch 8/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5144 - loss: 5.0997 - val_accuracy: 0.5186 - val_loss: 0.3126 - learning_rate: 0.0010
# Epoch 9/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.5125 - loss: 0.7837 - val_accuracy: 0.5398 - val_loss: 0.3396 - learning_rate: 0.0010
# Epoch 10/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.5227 - loss: 1.7266 - val_accuracy: 0.5420 - val_loss: 0.4181 - learning_rate: 0.0010
# Epoch 11/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.5419 - loss: 9.1691 - val_accuracy: 0.5520 - val_loss: 0.2427 - learning_rate: 0.0010
# Epoch 12/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - accuracy: 0.5375 - loss: 1.3512 - val_accuracy: 0.5417 - val_loss: 0.3579 - learning_rate: 0.0010
# Epoch 13/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 44s 23ms/step - accuracy: 0.5205 - loss: 1.4166 - val_accuracy: 0.5224 - val_loss: 0.5641 - learning_rate: 0.0010
# Epoch 14/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - accuracy: 0.5304 - loss: 0.7548 - val_accuracy: 0.5680 - val_loss: 0.3397 - learning_rate: 0.0010
# Epoch 15/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 43s 22ms/step - accuracy: 0.5318 - loss: 0.8050 - val_accuracy: 0.5364 - val_loss: 0.3747 - learning_rate: 0.0010
# Epoch 16/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.5189 - loss: 1.3792 - val_accuracy: 0.5457 - val_loss: 0.3656 - learning_rate: 0.0010
# Epoch 17/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.5424 - loss: 0.8186 - val_accuracy: 0.5416 - val_loss: 0.3091 - learning_rate: 0.0010
# Epoch 18/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5010 - loss: 0.7946 - val_accuracy: 0.5328 - val_loss: 0.2383 - learning_rate: 0.0010
# Epoch 19/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5315 - loss: 0.4947 - val_accuracy: 0.5361 - val_loss: 0.4505 - learning_rate: 0.0010
# Epoch 20/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.5405 - loss: 0.8567 - val_accuracy: 0.4747 - val_loss: 1.0826 - learning_rate: 0.0010
# Epoch 21/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.5104 - loss: 0.8488 - val_accuracy: 0.5630 - val_loss: 0.4226 - learning_rate: 0.0010
# Epoch 22/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.5248 - loss: 0.8915 - val_accuracy: 0.5445 - val_loss: 0.2802 - learning_rate: 0.0010
# Epoch 23/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - accuracy: 0.5342 - loss: 1.1210 - val_accuracy: 0.5431 - val_loss: 0.3661 - learning_rate: 0.0010
# Epoch 24/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5234 - loss: 0.5462 - val_accuracy: 0.5210 - val_loss: 26.6358 - learning_rate: 0.0010
# Epoch 25/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 20ms/step - accuracy: 0.5174 - loss: 0.6006 - val_accuracy: 0.5371 - val_loss: 0.4574 - learning_rate: 0.0010
# Epoch 26/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.5090 - loss: 0.9953 - val_accuracy: 0.5542 - val_loss: 0.3420 - learning_rate: 0.0010
# Epoch 27/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.5255 - loss: 0.7989 - val_accuracy: 0.5308 - val_loss: 0.4270 - learning_rate: 0.0010
# Epoch 28/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - accuracy: 0.5001 - loss: 0.6219 - val_accuracy: 0.5212 - val_loss: 0.3641 - learning_rate: 0.0010
# Epoch 29/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.4800 - loss: 0.9883 - val_accuracy: 0.4967 - val_loss: 0.4383 - learning_rate: 0.0010
# Epoch 30/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4825 - loss: 0.7352 - val_accuracy: 0.5256 - val_loss: 0.4520 - learning_rate: 0.0010
# Epoch 31/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - accuracy: 0.5022 - loss: 1.2530 - val_accuracy: 0.5055 - val_loss: 0.4029 - learning_rate: 0.0010
# Epoch 32/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.4412 - loss: 1.0503 - val_accuracy: 0.5491 - val_loss: 0.3216 - learning_rate: 0.0010
# Epoch 33/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 20ms/step - accuracy: 0.5099 - loss: 0.7423 - val_accuracy: 0.5075 - val_loss: 0.3392 - learning_rate: 0.0010
# Epoch 34/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5302 - loss: 0.9312 - val_accuracy: 0.5377 - val_loss: 0.4436 - learning_rate: 0.0010
# Epoch 35/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - accuracy: 0.5184 - loss: 0.5677 - val_accuracy: 0.5546 - val_loss: 0.3341 - learning_rate: 0.0010
# Epoch 36/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 44s 21ms/step - accuracy: 0.5391 - loss: 0.3850 - val_accuracy: 0.5503 - val_loss: 0.2523 - learning_rate: 0.0010
# Epoch 37/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.5439 - loss: 0.4587 - val_accuracy: 0.5428 - val_loss: 0.2910 - learning_rate: 0.0010
# Epoch 38/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5234 - loss: 0.5105 - val_accuracy: 0.5188 - val_loss: 0.2753 - learning_rate: 0.0010
# Epoch 39/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - accuracy: 0.5346 - loss: 0.5739 - val_accuracy: 0.4979 - val_loss: 0.3348 - learning_rate: 0.0010
# Epoch 40/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.5088 - loss: 0.6419 - val_accuracy: 0.5478 - val_loss: 0.2757 - learning_rate: 0.0010
# Epoch 41/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 44s 21ms/step - accuracy: 0.5243 - loss: 1.4681 - val_accuracy: 0.5431 - val_loss: 0.4231 - learning_rate: 0.0010
# Epoch 42/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.4883 - loss: 0.6546 - val_accuracy: 0.5364 - val_loss: 0.2683 - learning_rate: 0.0010
# Epoch 43/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - accuracy: 0.5267 - loss: 0.7983 - val_accuracy: 0.4894 - val_loss: 0.3648 - learning_rate: 0.0010
# Epoch 44/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.5280 - loss: 0.4315 - val_accuracy: 0.5223 - val_loss: 0.3163 - learning_rate: 0.0010
# Epoch 45/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 20ms/step - accuracy: 0.5132 - loss: 0.5296 - val_accuracy: 0.4960 - val_loss: 0.2892 - learning_rate: 0.0010
# Epoch 46/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 21ms/step - accuracy: 0.4990 - loss: 0.5504 - val_accuracy: 0.4546 - val_loss: 0.2462 - learning_rate: 0.0010
# Epoch 47/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 46s 24ms/step - accuracy: 0.4296 - loss: 0.7675 - val_accuracy: 0.5214 - val_loss: 0.3171 - learning_rate: 0.0010
# Epoch 48/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.4939 - loss: 0.6594 - val_accuracy: 0.5446 - val_loss: 0.3200 - learning_rate: 0.0010
# Epoch 49/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - accuracy: 0.5238 - loss: 0.9054 - val_accuracy: 0.5236 - val_loss: 0.2661 - learning_rate: 0.0010
# Epoch 50/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.4932 - loss: 0.7883 - val_accuracy: 0.4818 - val_loss: 0.3050 - learning_rate: 0.0010
# Epoch 51/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.4891 - loss: 0.4615 - val_accuracy: 0.5328 - val_loss: 1.2207 - learning_rate: 0.0010
# Epoch 52/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - accuracy: 0.5242 - loss: 0.5783 - val_accuracy: 0.5396 - val_loss: 1.6611 - learning_rate: 0.0010
# Epoch 53/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.4969 - loss: 0.6805 - val_accuracy: 0.3433 - val_loss: 0.4301 - learning_rate: 0.0010
# Epoch 54/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4917 - loss: 0.6345 - val_accuracy: 0.4893 - val_loss: 7.7868 - learning_rate: 0.0010
# Epoch 55/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.4989 - loss: 4.5177 - val_accuracy: 0.5187 - val_loss: 1.0505 - learning_rate: 0.0010
# Epoch 56/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5271 - loss: 0.7340 - val_accuracy: 0.5194 - val_loss: 0.3895 - learning_rate: 0.0010
# Epoch 57/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.5389 - loss: 0.5302 - val_accuracy: 0.5013 - val_loss: 0.3424 - learning_rate: 0.0010
# Epoch 58/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 21ms/step - accuracy: 0.5337 - loss: 0.6158 - val_accuracy: 0.4792 - val_loss: 0.3970 - learning_rate: 0.0010
# Epoch 59/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.4687 - loss: 4.7402 - val_accuracy: 0.5000 - val_loss: 0.3378 - learning_rate: 0.0010
# Epoch 60/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4924 - loss: 0.6083 - val_accuracy: 0.4764 - val_loss: 0.6358 - learning_rate: 0.0010
# Epoch 61/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4968 - loss: 0.9980 - val_accuracy: 0.5238 - val_loss: 0.2876 - learning_rate: 0.0010
# Epoch 62/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - accuracy: 0.5143 - loss: 0.6372 - val_accuracy: 0.5390 - val_loss: 0.2888 - learning_rate: 0.0010
# Epoch 63/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - accuracy: 0.5100 - loss: 0.6373 - val_accuracy: 0.5242 - val_loss: 0.3593 - learning_rate: 0.0010
# Epoch 64/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.5189 - loss: 0.5317 - val_accuracy: 0.5183 - val_loss: 0.3297 - learning_rate: 0.0010
# Epoch 65/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.5203 - loss: 0.8348 - val_accuracy: 0.5475 - val_loss: 0.3122 - learning_rate: 0.0010
# Epoch 66/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.5089 - loss: 0.6860 - val_accuracy: 0.5246 - val_loss: 0.3070 - learning_rate: 0.0010
# Epoch 67/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4899 - loss: 0.5110 - val_accuracy: 0.5051 - val_loss: 0.3291 - learning_rate: 0.0010
# Epoch 68/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - accuracy: 0.4239 - loss: 0.7226 - val_accuracy: 0.5176 - val_loss: 0.3217 - learning_rate: 0.0010
# Epoch 69/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - accuracy: 0.5098 - loss: 0.5367 - val_accuracy: 0.5536 - val_loss: 0.3496 - learning_rate: 0.0010
# Epoch 70/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.4152 - loss: 0.8507 - val_accuracy: 0.4867 - val_loss: 0.3284 - learning_rate: 0.0010
# Epoch 71/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4240 - loss: 0.9079 - val_accuracy: 0.5330 - val_loss: 0.4271 - learning_rate: 0.0010
# Epoch 72/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.4551 - loss: 0.6639 - val_accuracy: 0.5288 - val_loss: 0.3232 - learning_rate: 0.0010
# Epoch 73/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4951 - loss: 0.5444 - val_accuracy: 0.4852 - val_loss: 0.3694 - learning_rate: 0.0010
# Epoch 74/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.5020 - loss: 0.5721 - val_accuracy: 0.3873 - val_loss: 0.4349 - learning_rate: 0.0010
# Epoch 75/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - accuracy: 0.3568 - loss: 0.9035 - val_accuracy: 0.5196 - val_loss: 0.4500 - learning_rate: 0.0010
# Epoch 76/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.5123 - loss: 1.0427 - val_accuracy: 0.5213 - val_loss: 0.3203 - learning_rate: 0.0010
# Epoch 77/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - accuracy: 0.5127 - loss: 0.9685 - val_accuracy: 0.3594 - val_loss: 0.3306 - learning_rate: 0.0010
# Epoch 78/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.4894 - loss: 1.9529 - val_accuracy: 0.1319 - val_loss: 1.8607 - learning_rate: 0.0010
# Epoch 79/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - accuracy: 0.3302 - loss: 1.2244 - val_accuracy: 0.3872 - val_loss: 0.3109 - learning_rate: 0.0010
# Epoch 80/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - accuracy: 0.4327 - loss: 0.7322 - val_accuracy: 0.4926 - val_loss: 0.4213 - learning_rate: 0.0010
# Epoch 81/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.4357 - loss: 1.9509 - val_accuracy: 0.4964 - val_loss: 0.4500 - learning_rate: 0.0010
# Epoch 82/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4566 - loss: 0.8312 - val_accuracy: 0.4804 - val_loss: 0.2865 - learning_rate: 0.0010
# Epoch 83/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.4710 - loss: 0.8775 - val_accuracy: 0.4729 - val_loss: 0.2684 - learning_rate: 0.0010
# Epoch 84/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.4842 - loss: 0.7884 - val_accuracy: 0.4833 - val_loss: 0.3151 - learning_rate: 0.0010
# Epoch 85/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 35s 21ms/step - accuracy: 0.4899 - loss: 0.9270 - val_accuracy: 0.4853 - val_loss: 0.4355 - learning_rate: 0.0010
# Epoch 86/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 37s 21ms/step - accuracy: 0.4597 - loss: 0.6885 - val_accuracy: 0.4766 - val_loss: 0.3435 - learning_rate: 0.0010
# Epoch 87/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 41s 21ms/step - accuracy: 0.4877 - loss: 0.8850 - val_accuracy: 0.5323 - val_loss: 0.6179 - learning_rate: 0.0010
# Epoch 88/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.5029 - loss: 0.9060 - val_accuracy: 0.5327 - val_loss: 0.4316 - learning_rate: 0.0010
# Epoch 89/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 42s 20ms/step - accuracy: 0.5061 - loss: 1.1401 - val_accuracy: 0.5075 - val_loss: 0.4236 - learning_rate: 0.0010
# Epoch 90/300
# 1721/1721 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - accuracy: 0.4669 - loss: 0.8258 - val_accuracy: 0.5008 - val_loss: 0.4030 - learning_rate: 0.0010
# Epoch 91/300
# 1425/1721 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.4196 - loss: 1.1619

# %%
# Predict and evaluate
#y_pred = autoencoder.predict(x_test) # Use the trained autoencoder to predict
mse = mean_squared_error(x_test, y_pred) # Calculate MSE

# Resource usage
cpu_start = psutil.cpu_percent(interval=1)
memory_start = psutil.virtual_memory().percent

inference_time = end_time - start_time

cpu_end = psutil.cpu_percent(interval=1)
memory_end = psutil.virtual_memory().percent

energy_consumption = inference_time * (cpu_end - cpu_start + memory_end - memory_start)

print(f"Mean Squared Error: {mse:.4f}")
print(f"Inference Time: {inference_time:.4f} seconds")
print(f"Estimated Energy Consumption: {energy_consumption:.4f} (proxy value)")

# Plotting
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Metrics Plot
plt.subplot(1, 2, 2)
plt.bar(['MSE'], [mse], color='skyblue')
plt.title('Mean Squared Error')
plt.ylabel('Values')

plt.tight_layout()
plt.show()

# %%
# You can also plot the encoded representations and the reconstructed outputs for further analysis
#encoded_imgs = encoder.predict(x_test)
#decoded_imgs = autoencoder.predict(x_test)

# Extract the encoder model
encoder = models.Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('encoded_layer').output)

# You can also plot the encoded representations and the reconstructed outputs for further analysis
#encoded_imgs = encoder.predict(x_test)  # Now using the defined 'encoder'
#decoded_imgs = autoencoder.predict(x_test)

# Visualizing the original, encoded, and reconstructed signals
n = 10  # Number of samples to plot
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(3, n, i + 1)
    plt.plot(x_test[i])
    plt.title("Original")

    # Encoded
    ax = plt.subplot(3, n, i + 1 + n)
    plt.plot(encoded_imgs[i])
    plt.title("Encoded")

    # Reconstructed
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.plot(decoded_imgs[i])
    plt.title("Reconstructed")
plt.show()

# %%
# Plot training history
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy') # Changed from 'mean_squared_error' to 'accuracy'
plt.plot(history.history['val_accuracy'], label='Validation Accuracy') # Changed from 'val_mae' to 'val_accuracy'
plt.title('Accuracy') # Changed title to reflect the correct metric
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Additional checks
# Removed the accuracy calculation and overfitting check as they were not appropriate for this model

# %%
import sklearn.metrics as metrics # Import the metrics module from sklearn
#predictions = autoencoder.predict(x_test)
mse = metrics.mean_squared_error(x_test, predictions) # Use metrics.mean_squared_error
r2 = metrics.r2_score(x_test, predictions) # Use metrics.r2_score

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')

# Plotting Loss Curve
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.legend()

# Plotting Actual vs Predicted
#plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(x_test[0], label='Actual Signal')
plt.plot(predictions[0], label='Reconstructed Signal')
plt.title('Actual vs Reconstructed EEG Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()


plt.tight_layout()
plt.show()

# %%
# Function to plot original and reconstructed signals
def plot_signal_comparison(original, reconstructed, num_signals=5):
    plt.figure(figsize=(15, num_signals * 3))
    for i in range(num_signals):
        # Original Signal
        plt.subplot(num_signals, 2, 2*i + 1)
        plt.plot(original[i], color='blue')
        plt.title(f'Original Signal {i+1}')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.grid(True)

        # Reconstructed Signal
        plt.subplot(num_signals, 2, 2*i + 2)
        plt.plot(reconstructed[i], color='red')
        plt.title(f'Reconstructed Signal {i+1}')
        plt.xlabel('Time')
        plt.ylabel('Amplitude')
        plt.grid(True)
    plt.tight_layout()
    plt.show()

# Plotting comparison
plot_signal_comparison(x_test, predictions, num_signals=3)

# %%
activation = hp.Choice('activation', ['relu', 'elu', 'swish'])
    if activation == 'swish':
        activation_func = swish
    elif activation == 'elu':
        activation_func = 'elu'
    else:
        activation_func = 'relu'

optimizer = hp.Choice('optimizer', ['AdamW', 'RMSprop', 'SGD'])
    if activation == 'AdamW':
        # Dynamic optimizer selection (AdamW with weight decay)
        tf.keras.optimizers.AdamW(learning_rate=learning_rate, weight_decay=weight_decay)
    elif activation == 'RMSprop':
         tf.keras.optimizers.RMSprop(learning_rate=learning_rate)  # Dynamic learning rate
    else:
       tf.keras.optimizers.SGD(learning_rate=learning_rate)  # Dynamic learning rate
